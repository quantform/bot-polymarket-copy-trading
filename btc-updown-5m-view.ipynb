// %%
import { display } from 'tslab';
import { marked } from 'marked';
import { writeFileSync } from 'fs';
import { execSync } from 'child_process';
import { Module, core, logger } from '@quantform/core';

function svg(spec: unknown) {
  writeFileSync('./.jupiter/spec.vl.json', JSON.stringify(spec));

  const svg = execSync('npx vl2svg ./.jupiter/spec.vl.json', {
    encoding: 'utf8'
  });

  return display.html(svg);
}

async function md(text: string) {
  return display.html(await marked(text));
}

const module = new Module([
  ...core(),
  logger({
    for: context => ({
      info: () => {},
      debug: () => {},
      warn: () => {},
      error: () => console.log(context)
    })
  })
]);

const { act } = await module.awake();

// %%
import { lastValueFrom, switchMap, map, tap } from 'rxjs';
import { queryMarket } from './src/polymarket/query-market';
import { queryUserActivity } from './src/polymarket/query-user-activity';

const userWallet = '0x1d0034134e339a309700Ff2D34e99FA2d48b0313';
const timestamp = 1772056200;

//0x1d0034134e

const userActivity: any[] = await act(() =>
  lastValueFrom(
    queryMarket(`btc-updown-5m-${timestamp}`).pipe(
      switchMap(it => queryUserActivity(it.conditionId, userWallet)),
      map((it: any[]) => it.filter(it => it.type == 'TRADE'))
    )
  )
);

// %%
const start = timestamp;

const up = new Array(300).fill(0);
const down = new Array(300).fill(0);

for (const a of userActivity) {
  const sec = a.timestamp - start;
  if (sec < 0 || sec >= 300) continue;

  if (a.outcome === 'Up') {
    up[sec] += a.size;
  } else {
    down[sec] += a.size;
  }
}

// cumulative
for (let i = 1; i < 300; i++) {
  up[i] += up[i - 1];
  down[i] += down[i - 1];
}

const data = [];

for (let i = 0; i < 300; i++) {
  data.push({ sec: i, side: 'Up', value: up[i] });
  data.push({ sec: i, side: 'Down', value: down[i] });
}

const spec = {
  $schema: 'https://vega.github.io/schema/vega-lite/v5.json',
  width: 1000,
  height: 400,
  data: { values: data },
  mark: 'line',
  encoding: {
    x: { field: 'sec', type: 'quantitative', title: 'Seconds' },
    y: { field: 'value', type: 'quantitative', title: 'Cumulative Size' },
    color: { field: 'side', type: 'nominal' }
  }
};

svg(spec);
// Out:
// <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" class="marks" width="1138" height="447" viewBox="0 0 1138 447"><rect width="1138" height="447" fill="white"/><g fill="none" stroke-miterlimit="10" transform="translate(67,10)"><g class="mark-group role-frame root" role="graphics-object" aria-roledescription="group mark container"><g transform="translate(0,0)"><path class="background" aria-hidden="true" d="M0.5,0.5h1000v400h-1000Z" stroke="#ddd"/><g><g class="mark-group role-axis" aria-hidden="true"><g transform="translate(0.5,400.5)"><path class="background" aria-hidden="true" d="M0,0h0v0h0Z" pointer-events="none"/><g><g class="mark-rule role-axis-grid" pointer-events="none"><line transform="translate(0,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(33,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(67,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(100,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(133,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(167,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(200,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(233,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(267,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(300,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(333,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(367,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(400,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(433,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(467,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(500,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(533,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(567,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(600,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(633,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(667,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(700,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(733,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(767,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(800,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(833,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(867,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(900,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(933,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(967,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(1000,-400)" x2="0" y2="400" stroke="#ddd" stroke-width="1" opacity="1"/></g></g><path class="foreground" aria-hidden="true" d="" pointer-events="none" display="none"/></g></g><g class="mark-group role-axis" aria-hidden="true"><g transform="translate(0.5,0.5)"><path class="background" aria-hidden="true" d=" ...
// UnhandledPromiseRejection: Error: Unexpected pending rebuildTimer
//     at sys.setTimeout (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/converter.js:111:19)
//     at scheduleProgramUpdate (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/node_modules/@tslab/typescript-for-tslab/lib/typescript.js:122735:35)
//     at onSourceFileChange (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/node_modules/@tslab/typescript-for-tslab/lib/typescript.js:122876:7)
//     at /Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/node_modules/@tslab/typescript-for-tslab/lib/typescript.js:122868:56
//     at updateContent (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/converter.js:601:9)
//     at Object.complete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/converter.js:357:9)
//     at Object.complete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/executor.js:195:21)
//     at JupyterHandlerImpl.handleComplete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/jupyter.js:304:36)
//     at ZmqServer.handleComplete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/jupyter.js:425:38)
//     at ZmqServer.handleShellMessage (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/jupyter.js:360:26)
// UnhandledPromiseRejection: Error: Unexpected pending rebuildTimer
//     at sys.setTimeout (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/converter.js:111:19)
//     at scheduleProgramUpdate (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/node_modules/@tslab/typescript-for-tslab/lib/typescript.js:122735:35)
//     at onSourceFileChange (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/node_modules/@tslab/typescript-for-tslab/lib/typescript.js:122876:7)
//     at /Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/node_modules/@tslab/typescript-for-tslab/lib/typescript.js:122868:56
//     at updateContent (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/converter.js:601:9)
//     at Object.complete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/converter.js:357:9)
//     at Object.complete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/executor.js:195:21)
//     at JupyterHandlerImpl.handleComplete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/jupyter.js:304:36)
//     at ZmqServer.handleComplete (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/jupyter.js:425:38)
//     at ZmqServer.handleShellMessage (/Users/mateusz/.nvm/versions/node/v23.11.0/lib/node_modules/tslab/dist/jupyter.js:360:26)

// %%
const start = timestamp;

const up = new Array(300).fill(0);
const down = new Array(300).fill(0);

for (const a of userActivity) {
  const sec = a.timestamp - start;
  if (sec < 0 || sec >= 300) continue;

  if (a.outcome === 'Up') {
    up[sec] = a.price;
  } else {
    down[sec] = a.price;
  }
}

const data = [];

for (let i = 0; i < 300; i++) {
  data.push({ sec: i, side: 'Up', value: up[i] });
  data.push({ sec: i, side: 'Down', value: down[i] });
}

const spec = {
  $schema: 'https://vega.github.io/schema/vega-lite/v5.json',
  width: 1000,
  height: 400,
  data: { values: data },
  mark: 'bar',
  encoding: {
    x: {
      field: 'sec',
      type: 'ordinal',
      title: 'Seconds'
    },
    y: {
      field: 'value',
      type: 'quantitative',
      stack: 'zero',
      title: 'Price'
    },
    color: {
      field: 'side',
      type: 'nominal',
      scale: {
        domain: ['Up', 'Down'],
        range: ['#1f77b4', '#d62728']
      }
    }
  }
};

svg(spec);
// Out:
// <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" class="marks" width="1122" height="462" viewBox="0 0 1122 462"><rect width="1122" height="462" fill="white"/><g fill="none" stroke-miterlimit="10" transform="translate(51,10)"><g class="mark-group role-frame root" role="graphics-object" aria-roledescription="group mark container"><g transform="translate(0,0)"><path class="background" aria-hidden="true" d="M0.5,0.5h1000v400h-1000Z" stroke="#ddd"/><g><g class="mark-group role-axis" aria-hidden="true"><g transform="translate(0.5,0.5)"><path class="background" aria-hidden="true" d="M0,0h0v0h0Z" pointer-events="none"/><g><g class="mark-rule role-axis-grid" pointer-events="none"><line transform="translate(0,400)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,360)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,320)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,280)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,240)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,200)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,160)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,120)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,80)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,40)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(0,0)" x2="1000" y2="0" stroke="#ddd" stroke-width="1" opacity="1"/></g></g><path class="foreground" aria-hidden="true" d="" pointer-events="none" display="none"/></g></g><g class="mark-group role-axis" role="graphics-symbol" aria-roledescription="axis" aria-label="X-axis titled 'Seconds' for a discrete scale with 300 values: 0, 1, 2, 3, 4, ending with 299"><g transform="translate(0.5,400.5)"><path class="background" aria-hidden="true" d="M0,0h0v0h0Z" pointer-events="none"/><g><g class="mark-rule role-axis-tick" pointer-events="none"><line transform="translate(1,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(5,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(8,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(11,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(15,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(18,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(21,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(25,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(28,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(31,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(35,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(38,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(41,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(45,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(48,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(51,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(55,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(58,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><line transform="translate(61,0)" x2="0" y2="5" stroke="#888" stroke-width="1" opacity="1"/><li ...

// %%
function buildExecutionSpec(userActivity) {
  const start = timestamp;

  const seconds = 300;

  const payoutUp = new Array(seconds).fill(0);
  const payoutDown = new Array(seconds).fill(0);
  const costUp = new Array(seconds).fill(0);
  const costDown = new Array(seconds).fill(0);

  for (const a of userActivity) {
    const sec = Math.floor(a.timestamp - start);
    if (sec < 0 || sec >= seconds) continue;

    if (a.outcome === 'Up') {
      payoutUp[sec] += a.size;
      costUp[sec] += a.size * a.price;
    } else {
      payoutDown[sec] += a.size;
      costDown[sec] += a.size * a.price;
    }
  }

  // cumulative
  for (let i = 1; i < seconds; i++) {
    payoutUp[i] += payoutUp[i - 1];
    payoutDown[i] += payoutDown[i - 1];
    costUp[i] += costUp[i - 1];
    costDown[i] += costDown[i - 1];
  }

  const values = [];

  for (let i = 0; i < seconds; i++) {
    const totalCost = costUp[i] + costDown[i];
    const riskUp = payoutUp[i] - totalCost;
    const riskDown = payoutDown[i] - totalCost;

    values.push({
      sec: i,
      payoutUp: payoutUp[i],
      payoutDown: payoutDown[i],
      totalCost,
      riskUp,
      riskDown
    });
  }

  return {
    $schema: 'https://vega.github.io/schema/vega-lite/v5.json',
    vconcat: [
      {
        width: 1000,
        height: 300,
        title: 'Payout vs Cost',
        data: { values },
        layer: [
          {
            mark: 'line',
            encoding: {
              x: { field: 'sec', type: 'quantitative', title: 'Seconds' },
              y: { field: 'payoutUp', type: 'quantitative', title: 'USD' },
              color: { value: '#1f77b4' }
            }
          },
          {
            mark: 'line',
            encoding: {
              x: { field: 'sec', type: 'quantitative' },
              y: { field: 'payoutDown', type: 'quantitative' },
              color: { value: '#d62728' }
            }
          },
          {
            mark: { type: 'line', strokeDash: [4, 4] },
            encoding: {
              x: { field: 'sec', type: 'quantitative' },
              y: { field: 'totalCost', type: 'quantitative' },
              color: { value: '#000000' }
            }
          }
        ]
      },
      {
        width: 1000,
        height: 300,
        title: 'Risk Surface (PnL if resolves now)',
        data: { values },
        layer: [
          {
            mark: 'line',
            encoding: {
              x: { field: 'sec', type: 'quantitative' },
              y: { field: 'riskUp', type: 'quantitative', title: 'PnL' },
              color: { value: '#1f77b4' }
            }
          },
          {
            mark: 'line',
            encoding: {
              x: { field: 'sec', type: 'quantitative' },
              y: { field: 'riskDown', type: 'quantitative' },
              color: { value: '#d62728' }
            }
          },
          {
            mark: { type: 'rule', color: 'gray' },
            encoding: {
              y: { datum: 0 }
            }
          }
        ]
      }
    ]
  };
}

svg(buildExecutionSpec(userActivity));
// Out:
// <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" class="marks" width="1075" height="737" viewBox="0 0 1075 737"><rect width="1075" height="737" fill="white"/><g fill="none" stroke-miterlimit="10" transform="translate(68,23)"><g class="mark-group role-frame root" role="graphics-object" aria-roledescription="group mark container"><g transform="translate(0,0)"><path class="background" aria-hidden="true" d="M0,0h1000v0h-1000Z"/><g><g class="mark-group role-scope concat_0_group" role="graphics-object" aria-roledescription="group mark container"><g transform="translate(0,0)"><path class="background" aria-hidden="true" d="M0.5,0.5h1000v300h-1000Z" stroke="#ddd"/><g><g class="mark-group role-axis" aria-hidden="true"><g transform="translate(0.5,300.5)"><path class="background" aria-hidden="true" d="M0,0h0v0h0Z" pointer-events="none"/><g><g class="mark-rule role-axis-grid" pointer-events="none"><line transform="translate(0,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(33,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(67,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(100,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(133,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(167,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(200,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(233,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(267,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(300,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(333,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(367,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(400,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(433,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(467,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(500,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(533,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(567,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(600,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(633,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(667,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(700,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(733,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(767,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(800,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(833,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(867,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(900,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(933,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(967,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(1000,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/></g></g><path class ...

// %%
function buildStageSpec(userActivity) {
  const start = timestamp;
  const seconds = 300;

  const payoutUp = new Array(seconds).fill(0);
  const payoutDown = new Array(seconds).fill(0);

  for (const a of userActivity) {
    const sec = Math.floor(a.timestamp - start);
    if (sec < 0 || sec >= seconds) continue;

    if (a.outcome === 'Up') {
      payoutUp[sec] += a.size;
    } else {
      payoutDown[sec] += a.size;
    }
  }

  for (let i = 1; i < seconds; i++) {
    payoutUp[i] += payoutUp[i - 1];
    payoutDown[i] += payoutDown[i - 1];
  }

  const values = [];

  for (let i = 0; i < seconds; i++) {
    const up = payoutUp[i];
    const down = payoutDown[i];

    const skew = up - down;

    const hedge = Math.max(up, down) === 0 ? 0 : Math.min(up, down) / Math.max(up, down);

    values.push({
      sec: i,
      skew,
      hedge
    });
  }

  return {
    $schema: 'https://vega.github.io/schema/vega-lite/v5.json',
    vconcat: [
      {
        width: 1000,
        height: 300,
        title: 'Directional Exposure (Inventory Skew)',
        data: { values },
        mark: 'line',
        encoding: {
          x: { field: 'sec', type: 'quantitative' },
          y: { field: 'skew', type: 'quantitative', title: 'Up - Down' }
        }
      },
      {
        width: 1000,
        height: 300,
        title: 'Hedge Ratio (Stage Detector)',
        data: { values },
        layer: [
          {
            mark: 'line',
            encoding: {
              x: { field: 'sec', type: 'quantitative' },
              y: { field: 'hedge', type: 'quantitative', title: 'Hedge Ratio' }
            }
          },
          {
            mark: { type: 'rule', strokeDash: [4, 4] },
            encoding: { y: { datum: 0.3 } }
          },
          {
            mark: { type: 'rule', strokeDash: [4, 4] },
            encoding: { y: { datum: 0.8 } }
          }
        ]
      }
    ]
  };
}

svg(buildStageSpec(userActivity));
// Out:
// <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" class="marks" width="1067" height="742" viewBox="0 0 1067 742"><rect width="1067" height="742" fill="white"/><g fill="none" stroke-miterlimit="10" transform="translate(60,28)"><g class="mark-group role-frame root" role="graphics-object" aria-roledescription="group mark container"><g transform="translate(0,0)"><path class="background" aria-hidden="true" d="M0,0h1000v0h-1000Z"/><g><g class="mark-group role-scope concat_0_group" role="graphics-object" aria-roledescription="group mark container"><g transform="translate(0,0)"><path class="background" aria-hidden="true" d="M0.5,0.5h1000v300h-1000Z" stroke="#ddd"/><g><g class="mark-group role-axis" aria-hidden="true"><g transform="translate(0.5,300.5)"><path class="background" aria-hidden="true" d="M0,0h0v0h0Z" pointer-events="none"/><g><g class="mark-rule role-axis-grid" pointer-events="none"><line transform="translate(0,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(33,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(67,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(100,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(133,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(167,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(200,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(233,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(267,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(300,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(333,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(367,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(400,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(433,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(467,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(500,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(533,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(567,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(600,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(633,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(667,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(700,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(733,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(767,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(800,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(833,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(867,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(900,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(933,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(967,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/><line transform="translate(1000,-300)" x2="0" y2="300" stroke="#ddd" stroke-width="1" opacity="1"/></g></g><path class ...

// %% [markdown]
// - The trader starts trading ~10 seconds after market open, likely exploiting the delay between Bitcoin’s initial move and the orderbook repricing. This allows him to capture mispriced implied probabilities before market makers adjust.
